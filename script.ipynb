# %% [markdown]
# # Coding 组训练代码
# ## 1.测试KimberleyJensen的yaml和musdb18hq

# %%
python train.py \
    --model_type mel_band_roformer \
    --config_path configs/KimberleyJensen/config_vocals_mel_band_roformer_kj.yaml \
    --results_path results/ \
    --data_path '/23TW026/data/mss_data/musdb18hq/train' \
    --valid_path '/23TW026/data/mss_data/musdb18hq/test' \
    --num_workers 4 \
    --device_ids 0 1 2 3 \
    --wandb_key '9076158222bdbf82cf23c7bb5004a2d63e16c451'

# %% [markdown]
# ## 7. 测试Mel band Llama config 为我按照KimberleyJensen改的config_musdb18_vocals_mel_band_roformer_kj_with_augue.yaml

# %%
python train.py \
    --model_type mel_band_llama \
    --config_path configs/KimberleyJensen/config_musdb18_vocals_mel_llama.yaml \
    --results_path results/musdb18_vocals_mel_band_llama_kj_with_augue \
    --data_path '/23TW026/data/mss_data/musdb18hq/train' \
    --valid_path '/23TW026/data/mss_data/musdb18hq/test' \
    --num_workers 4 \
    --device_ids 1 2 3 4 \
    --wandb_key '9076158222bdbf82cf23c7bb5004a2d63e16c451'

# %% [markdown]
# ## 8. 测试Mel band roformer snake
# configs/KimberleyJensen/config_musdb18_vocals_mel_band_roformer_snake.yaml
#
# 结果loss为0，估计是值太大砍掉了

# %%
python train.py \
    --model_type mel_band_roformer_snake \
    --config_path configs/KimberleyJensen/config_musdb18_vocals_mel_band_roformer_snake.yaml \
    --results_path results/vocals_mel_band_roformer_snake \
    --data_path '/23TW026/data/mss_data/musdb18hq/train' \
    --valid_path '/23TW026/data/mss_data/musdb18hq/test' \
    --num_workers 4 \
    --device_ids 1 2 3 4 \
    --wandb_key '9076158222bdbf82cf23c7bb5004a2d63e16c451'

# %% [markdown]
# # 9. 测试SCNet Large only output vocal

# %%
python train.py \
    --model_type scnet \
    --config_path configs/config_musdb18_scnet_large.yaml \
    --results_path results/musdb18_scnet_large \
    --data_path '/23TW026/data/mss_data/musdb18hq/train' \
    --valid_path '/23TW026/data/mss_data/musdb18hq/test' \
    --num_workers 4 \
    --device_ids 1 2 3 4 \
    --wandb_key '9076158222bdbf82cf23c7bb5004a2d63e16c451'

# %% [markdown]
# # Task 组训练
# ## 1.测试KimberleyJensen的yaml和musdb18hq
# 结果：训练一天，到了4.26162就上升非常慢了

# %%
python train.py --model_type mel_band_roformer --config_path configs/KimberleyJensen/config_vocals_mel_band_roformer_kj.yaml --results_path results/ --data_path '/23TW026/data/mss_data/musdb18hq/train' --valid_path '/23TW026/data/mss_data/musdb18hq/test' --num_workers 28 --device_ids 0 1 2 3 4 5 6 --wandb_key '9076158222bdbf82cf23c7bb5004a2d63e16c451'

# %% [markdown]
# # 2. 测试加了augmentation的作者提供的config_vocals_mel_band_roformer.yaml
# 结果：训练了三天到了6.64后上升就很慢了

# %%
python train.py --model_type mel_band_roformer --config_path configs/config_vocals_mel_band_roformer.yaml --results_path results/config_vocals_mel_band_roformer/ --data_path '/23TW026/data/mss_data/musdb18hq/train' --valid_path '/23TW026/data/mss_data/musdb18hq/test' --num_workers 32 --device_ids 0 1 2 3 4 5 6 7 --wandb_key '9076158222bdbf82cf23c7bb5004a2d63e16c451'

# %% [markdown]
# ## 3. 测试KJ的yaml加augmentation
# 结果：加了augmentation后并没有比没有加强太多，反而更低了

# %%
python train.py --model_type mel_band_roformer --config_path configs/KimberleyJensen/config_vocals_mel_band_roformer_kj_with_augue.yaml --results_path results/vocals_mel_band_roformer_kj_with_augue/ --data_path '/23TW026/data/mss_data/musdb18hq/train' --valid_path '/23TW026/data/mss_data/musdb18hq/test' --num_workers 32 --device_ids 0 1 2 3 4 5 6 7 --wandb_key '9076158222bdbf82cf23c7bb5004a2d63e16c451'

# %% [markdown]
# ## 4. 测试KJ的yaml加上他的pretrained
# 结果：KJ训练的模型能够达到12以上

# %%
python train.py --model_type mel_band_roformer --config_path configs/KimberleyJensen/config_vocals_mel_band_roformer_kj.yaml --start_check_point /23TW026/ckpt/melbandroformer/MelBandRoformer.ckpt --pre_valid --results_path results/vocals_mel_band_roformer_kj_pretrained/ --data_path '/23TW026/data/mss_data/musdb18hq/train' --valid_path '/23TW026/data/mss_data/musdb18hq/test' --num_workers 32 --device_ids 0 1 2 3 4 5 6 7 --wandb_key '9076158222bdbf82cf23c7bb5004a2d63e16c451'

# %% [markdown]
# ## 5. 测试config_musdb18_mel_band_roformer.yaml
# 前三个出现的问题：使用musdb18的时候一定要用这个作为yaml，因为它KJ那里是只有vocal 加 other，但是musdb18并不是other就是剩余的，白白浪费了一周
#
# 训练了四天到了9.2就很难上升了

# %%
python train.py --model_type mel_band_roformer --config_path configs/config_musdb18_mel_band_roformer.yaml --results_path results/musdb18_mel_band_roformer/ --data_path '/23TW026/data/mss_data/musdb18hq/train' --valid_path '/23TW026/data/mss_data/musdb18hq/test' --num_workers 32 --device_ids 0 1 2 3 4 5 6 7 --wandb_key '9076158222bdbf82cf23c7bb5004a2d63e16c451'

# %% [markdown]
# ## 6. 测试 我按照KimberleyJensen改的config_musdb18_vocals_mel_band_roformer_kj_with_augue.yaml
#
# 结果训了7天，到9.99796

# %%
python train.py --model_type mel_band_roformer --config_path configs/KimberleyJensen/config_musdb18_vocals_mel_band_roformer_kj_with_augue.yaml --results_path results/musdb18_vocals_mel_band_roformer_kj_with_augue/ --data_path '/23TW026/data/mss_data/musdb18hq/train' --valid_path '/23TW026/data/mss_data/musdb18hq/test' --num_workers 32 --device_ids 0 1 2 3 4 5 6 7 --wandb_key '9076158222bdbf82cf23c7bb5004a2d63e16c451'

# %%
python train.py --model_type mel_band_roformer --start_check_point /23TW026/mss/Music-Source-Separation-Training_fork/results/musdb18_vocals_mel_band_roformer_kj_with_augue/model_mel_band_roformer_ep_345_sdr_9.9993.ckpt --config_path configs/KimberleyJensen/config_musdb18_vocals_mel_band_roformer_kj_with_augue.yaml --results_path results/musdb18_vocals_mel_band_roformer_kj_with_augue/ --data_path '/23TW026/data/mss_data/musdb18hq/train' --valid_path '/23TW026/data/mss_data/musdb18hq/test' --num_workers 32 --device_ids 0 1 2 3 4 5 6 7 --wandb_key '9076158222bdbf82cf23c7bb5004a2d63e16c451'

# %% [markdown]
# ## 7. 测试Mel band Llama config 为我按照KimberleyJensen改的config_musdb18_vocals_mel_band_roformer_kj_with_augue.yaml
# 效果没roformer好

# %%
python train.py --model_type mel_band_llama --config_path configs/KimberleyJensen/config_musdb18_vocals_mel_llama.yaml --results_path results/musdb18_vocals_mel_band_llama_kj_with_augue --data_path '/23TW026/data/mss_data/musdb18hq/train' --valid_path '/23TW026/data/mss_data/musdb18hq/test' --num_workers 32 --device_ids 0 1 2 3 4 5 6 7 --wandb_key '9076158222bdbf82cf23c7bb5004a2d63e16c451'

# %% [markdown]
# # 9. 测试SCNet Large only output vocal
# 尝试了一下自己改的vocal，sdr很奇怪
#
# 尝试了自带的，出现nan
#
# 再尝试SCNet Large (by starrytong) * 还是nan，尝试带它的预训练模型

# %%
python train.py --model_type scnet --start_check_point /23TW026/ckpt/SCNet/SCNet-large_starrytong_fixed.ckpt --config_path configs/config_musdb18_scnet_large.yaml --results_path results/musdb18_scnet_large --data_path '/23TW026/data/mss_data/musdb18hq/train' --valid_path '/23TW026/data/mss_data/musdb18hq/test' --num_workers 32 --device_ids 0 1 2 3 4 5 6 7 --wandb_key '9076158222bdbf82cf23c7bb5004a2d63e16c451'

# %% [markdown]
# ## 10. 测试multi band roformer 其grad accumulate=2
#
# 训到8.88 停了，明显没有mel band 的好
#
# configs/config_musdb18_bs_roformer.yaml

# %%
python train.py --model_type bs_roformer --config_path configs/config_musdb18_bs_roformer.yaml --results_path results/bs_roformer/ --data_path '/23TW026/data/mss_data/musdb18hq/train' --valid_path '/23TW026/data/mss_data/musdb18hq/test' --num_workers 32 --device_ids 0 1 2 3 4 5 6 7 --wandb_key '9076158222bdbf82cf23c7bb5004a2d63e16c451'

# %% [markdown]
# ## 11. 测试multi band roformer big 其grad accumulate=2
#
# 结果：训练了10天，到10.00278就上不去了
#
# configs/KimberleyJensen/config_musdb18_bs_roformer_big.yaml

# %%
python train.py --model_type bs_roformer --config_path configs/KimberleyJensen/config_musdb18_bs_roformer_big.yaml --results_path results/bs_roformer_big/ --data_path '/23TW026/data/mss_data/musdb18hq/train' --valid_path '/23TW026/data/mss_data/musdb18hq/test' --num_workers 32 --device_ids 0 1 2 3 4 5 6 7 --wandb_key '9076158222bdbf82cf23c7bb5004a2d63e16c451'

# %% [markdown]
# # Inference
# ## 1.测试KimberleyJensen的yaml和musdb18hq

# %%
python inference.py \
    --model_type mel_band_roformer \
    --config_path configs/KimberleyJensen/config_vocals_mel_band_roformer_kj.yaml \
    --start_check_point results/model_mel_band_roformer_ep_57_sdr_4.2616.ckpt \
    --input_folder /23TW026/data/mss_data/multisong_dataset \
    --store_dir /23TW026/data/mss_data/mel_band_roformer_ep_57_multisong_separation_results/

# %% [markdown]
# ## 2. 测试加了augmentation的yaml

# %%
python inference.py \
    --model_type mel_band_roformer \
    --config_path configs/config_vocals_mel_band_roformer.yaml \
    --start_check_point results/config_vocals_mel_band_roformer/model_mel_band_roformer_ep_33_sdr_5.4923.ckpt \
    --input_folder /23TW026/data/mss_data/multisong_dataset \
    --store_dir /23TW026/data/mss_data/model_mel_band_roformer_ep_33_multisong_separation_results/

# %% [markdown]
# ## 6. 测试 我按照KimberleyJensen改的config_musdb18_vocals_mel_band_roformer_kj_with_augue.yaml
#
# 使用的是multisong_dataset,测试结果如下：
# ```
# WSF_MSST_MelFormer_KJ_Musdb18:
# SDR Vocals: 8.325318
# The MelFormer from KJ's pretrained model:
# SDR Instrumental: 17.285107
# SDR Vocals: 10.977636
# The SCNet send before:SDR Vocals: 8.261752
# SDR Drums: 10.776174
# SDR Bass: 10.974363
# SDR Other: 5.350250
# ```

# %%
python inference.py \
    --model_type mel_band_roformer \
    --config_path configs/KimberleyJensen/config_musdb18_vocals_mel_band_roformer_kj_with_augue.yaml \
    --start_check_point results/musdb18_vocals_mel_band_roformer_kj_with_augue/model_mel_band_roformer_ep_229_sdr_9.9637.ckpt \
    --input_folder /23TW026/data/mss_data/multisong_dataset \
    --store_dir /23TW026/data/mss_data/model_mel_band_roformer_ep_229_sdr_9.96_multisong_separation_results/

# %% [markdown]
# # Valid
# ## 4. valid KJ的yaml和他的pretrained
# 结果：没有重新微调的sdr为12.1373

# %%
python valid.py --model_type mel_band_roformer --config_path configs/KimberleyJensen/config_musdb18_vocals_mel_band_roformer_kj_with_augue.yaml --start_check_point /23TW026/ckpt/melbandroformer/MelBandRoformer.ckpt --valid_path '/23TW026/data/mss_data/musdb18hq/test' --num_workers 4 --device_ids 3
